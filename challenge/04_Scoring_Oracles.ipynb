# %% [markdown]
# ## Suggested Tools and Resources for Scoring Oracles
#
# 1. Recap of MolMIM NIM endpoint
# 2. Other Molecule Generation Models?
# 3. Scoring Mechanism
#     1. MolMIM, GenMol
#     2. RDKit (list common scoring tools within)
#     3. UniDock (package this as a reference container or provide a Dockerfile \+ build instructions)
#     4. DualBind
#     5. ReaSyn
#     6. MDSim:  GROMACS, NAMD
